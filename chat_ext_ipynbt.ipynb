# %%
# @markdown # Run for install and start
# %cd /content
# !apt-get update -y
# !apt-get install python3.10 python3.10-distutils
# !update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.10 100
#!update-alternatives --config python3
# !apt-get install python3-pip
# !python3 -m pip install --upgrade pip --user
# !python3 --version
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/shaitanzx/chatterbox_vc_mtl.git
# %cd /content/chatterbox_vc_mtl
# !python entry_with_update.py
# !pip install -r requirements.txt
# !python app.py --share

# %%
# @markdown # Run for restart
# %cd /content
# !git clone https://github.com/shaitanzx/chatterbox_vc_mtl.git
# %cd /content/chatterbox_vc_mtl
# !python entry_with_update.py
# !python app.py --share
